# %%
import pandas as pd

df = pd.read_csv(
    "lfads-torch/scripts/runs/lfads-torch-example/my_data_module20250325/251121_exampleSingle/csv_logs/metrics.csv",
    skipinitialspace=True,  # removes spaces after commas
    engine="python",        # more tolerant parser
    na_values=["nan", ""],  # treat 'nan' and empty as NaN
    dtype=str               # read everything as string to avoid dtype errors
)

print(df.shape)
df
# Out:
# (10, 42)
#   lr-AdamW step  valid/recon/sess0   valid/loss        valid/recon         \
# 0    0.002    0                 NaN               NaN                 NaN
# 1      NaN    3  0.907684326171875   9076.8427734375   0.907684326171875
# 2      NaN    3                 NaN               NaN                 NaN
# 3    0.002    4                 NaN               NaN                 NaN
# 4      NaN    7  0.756473183631897   7564.73193359375  0.756473183631897
# 5      NaN    7                 NaN               NaN                 NaN
# 6    0.002    8                 NaN               NaN                 NaN
# 7      NaN   11  0.5961896777153015  5961.89697265625  0.5961896777153015
# 8      NaN   11                 NaN               NaN                 NaN
# 9    0.002   12                 NaN               NaN                 NaN
#
#    valid/bps  valid/co_bps  valid/fp_bps  valid/r2 valid/wt_l2  ...  \
# 0        NaN           NaN           NaN       NaN         NaN  ...
# ...

# %%
import pandas as pd
import os

from IPython.display import display, HTML



csv_path = "/Users/berenakpinar/lfads-torch/lfads-torch/scripts/runs/lfads-torch-example/my_data_module20250325/251121_exampleSingle/csv_logs/metrics.csv"

# Print all columns in the DataFrame
pd.set_option('display.max_columns', None)

df = pd.read_csv(csv_path, skipinitialspace=True, engine="python", na_values=["nan", ""], dtype=str)
print("DataFrame shape:", df.shape)
print("All columns:")
print(df.columns.tolist())
display(HTML(df.to_html(max_rows=20)))
# Out:
# DataFrame shape: (10, 42)
# All columns:
# ['lr-AdamW', 'step', 'valid/recon/sess0 ', 'valid/loss      ', 'valid/recon       ', 'valid/bps', 'valid/co_bps', 'valid/fp_bps', 'valid/r2', 'valid/wt_l2', 'valid/wt_l2/ramp    ', 'valid/wt_kl', 'valid/wt_kl/ic', 'valid/wt_kl/co', 'valid/wt_kl/ramp    ', 'valid/recon_smth  ', 'hp_metric         ', 'cur_epoch', 'hp/lr_init           ', 'hp/dropout_rate     ', 'hp/l2_ic_enc_scale', 'hp/l2_ci_enc_scale', 'hp/l2_gen_scale', 'hp/l2_con_scale', 'hp/kl_co_scale', 'hp/kl_ic_scale', 'hp/weight_decay', 'hp/cd_rate         ', 'epoch', 'train/recon/sess0 ', 'train/loss       ', 'train/recon       ', 'train/bps', 'train/co_bps', 'train/fp_bps', 'train/r2', 'train/wt_l2', 'train/wt_l2/ramp    ', 'train/wt_kl', 'train/wt_kl/ic', 'train/wt_kl/co', 'train/wt_kl/ramp']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>lr-AdamW</th>
#       <th>step</th>
#       <th>valid/recon/sess0</th>
# ...
